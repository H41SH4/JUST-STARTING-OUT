# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns

import numpy as np

# %%
df = pd.read_json('your_posts_1.json')

df.rename(columns={'timestamp': 'date'}, inplace=True)
df = df.drop(['attachments', 'title', 'tags'], axis=1)
pd.to_datetime(df['date'])



df = df.set_index('date')

posts_counts = df['data'].resample('MS').size()

posts_counts.head(200)

# Setting up data viz

sns.set(rc={'figure.figsize': (40, 20)})
sns.set(font_scale = 3)

x_labels = posts_counts.index

sns.barplot(x_labels, posts_counts, color= 'blue')

tick_positions = np.arange(10, len(x_labels), step=24)

plt.xticks(tick_positions, x_labels[tick_positions].strftime('%Y'))

plt.show()
# Out:
# C:\Users\daiml\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
